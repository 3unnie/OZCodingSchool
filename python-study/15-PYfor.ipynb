# %%
#for 반복문

#for 변수 in range(횟수):
#   들여쓰기

고양이 = ["먼지","하루","모래"];

for i in 고양이:
    print(i);
# Out:
# 먼지
# 하루
# 모래

# %%
정수 = [10, 5, 8];
부호 = [True, False, True];

합 = 0;

for a, b in zip(부호,정수):
    if a:
        합 += b;
    else:
        합 -=b;

print (합);
# Out:
# 13
