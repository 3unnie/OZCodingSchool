# %%
def 먼지():
    print("첫째의 이름은 먼지입니다.");
def 하루():
    print("둘째의 이름은 하루입니다.");

먼지();
하루();
# Out:
# 첫째의 이름은 먼지입니다.
# 둘째의 이름은 하루입니다.

# %%
def sum(a,b):
    c = a+b;
    return c;

print(sum(1,2));
# Out:
# 3

# %%
a = 1;
b = 0;

def 글로벌():
    c= a+b;

    return c;

print(글로벌());
# Out:
# 1
