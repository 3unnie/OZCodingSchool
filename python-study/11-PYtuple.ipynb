# %%
#tuple

#리스트 처럼 요소를 일렬로 저장하지만 안에 저장된 요소를 변경 추가 삭제 할수없다

튜플 = (1,"먼지",2,"하루");
리스트 =[1,"먼지",2,"하루"];
튜플2 = 1,"먼지",2,"하루"; #가능

print(type(튜플));
print(type(리스트));
print(type(튜플2));

튜플_솔로 = (1,);
print(type(튜플_솔로));
# Out:
# <class 'tuple'>
# <class 'list'>
# <class 'tuple'>
# <class 'tuple'>

# %%
print(dir(tuple));
print(dir(list));
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']
# ...

# %%
#튜플 리스트화

튜플2 = list(튜플2);
print(type(튜플2));

print(튜플2);
# Out:
# <class 'list'>
# [1, '먼지', 2, '하루']

# %%
고양이들="조먼지조하루";

고양이_list = list(고양이들);
고양이_tuple = tuple(고양이들);

마벱="".join(고양이_list);
마벱2="".join(고양이_list);
print("리스트:"+마벱);
print("tuple:"+마벱2);
# Out:
# 리스트:조먼지조하루
# tuple:조먼지조하루
