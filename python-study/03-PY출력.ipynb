# %%
# 주석입니다.

# %%
# """
#     여러줄 주석은 이렇게
# """ (colab은 안된다...)

# %%
for animal in ("고양이","강아지","뱀"):
    print("동물 보러갈랭?");
    print(animal)
# Out:
# 동물 보러갈랭?
# 고양이
# 동물 보러갈랭?
# 강아지
# 동물 보러갈랭?
# 뱀
