# %% [markdown]
# 안녕하세요
# # 조먼지
# ## 조먼지
# ### 조먼지
# #### 조먼지
# ##### 조먼지

# %%
print("안녕하세요 선생님")
print("안녕하세요 선생님")
print("안녕하세요 선생님")
print("안녕하세요 선생님")
# Out:
# 안녕하세요 선생님
# 안녕하세요 선생님
# 안녕하세요 선생님
# 안녕하세요 선생님

# %%
print("안녕~ 칭구야~")
# Out:
# 안녕~ 칭구야~
