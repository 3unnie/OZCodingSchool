# %%
#파일읽고쓰기

# %%
pwd
# Out:
# '/content'

# %%
ll
# Out:
# total 4
# drwxr-xr-x 1 root 4096 Apr  4 13:24 sample_data/

# %%
cd /content/note
# Out:
# /content/note

# %% [markdown]
# r 읽기
#
# w 쓰기(덮어쓰기)
#
# a 추가

# %%
f = open('test.txt','w')
f.write("안녕하세요")
f.write('''여러문장은
이렇게
쓰면
된다리
케케케''')
f.close()

# %%
f = open('test.txt','r')

print(f.read())

f.close()
# Out:
# 안녕하세요여러문장은
# 이렇게
# 쓰면
# 된다리
# 케케케

# %%
f = open('test.txt','r')
#한줄씩 읽어
print(f.readline())
f.close()
# Out:
# 안녕하세요여러문장은

# %%
with open('test.txt','w') as f:
    f.write("다른 방법")


list=[10,20,30]

with open('test.txt','w') as f:
    f.writelines(str(list)) #int는안된다

# %%
#csv파일

list = ['10','20','30']

with open('testcsv.csv','w') as f:
    f.write(','.join(list))
