# %% [markdown]
# 도전 과제입니다!!!
#
# 난이도가 다소 높은 문제이기 때문에 도전하지 않으셔도 됩니다.
#
# 실력을 높이시고 싶은 수강생 여러분은 무조건 도전해 주세요!!
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### [프로젝트: 간단한 주소록 관리 시스템]
#
# [목표]
# - 사용자로부터 연락처 정보를 입력받아 관리하고,<br>
# 원하는 조건에 따라 연락처를 검색할 수 있는 간단한 주소록 관리 시스템을 만듭니다.
#
# [기능]
# - 연락처 추가: 사용자의 이름, 전화번호, 이메일 주소를 입력받아 주소록에 추가합니다.
# - 연락처 목록 보기: 저장된 모든 연락처의 정보를 화면에 출력합니다.
# - 연락처 검색: 사용자로부터 검색 키워드를 입력받아, 해당 키워드가 이름에 포함된 연락처 정보를 화면에 출력합니다.
# - 연락처 삭제: 사용자로부터 이름을 입력받아, 해당하는 연락처 정보를 주소록에서 삭제합니다.
#
# [구현 상세]
# - 주소록 데이터는 리스트 내에 딕셔너리 형태로 저장됩니다.
# - 각 기능은 별도의 함수로 구현합니다.
# - 함수의 기본 활용, 가변 매개변수, 기본 매개변수, 키워드 매개변수, 타입 어노테이션,<br>
#   제너레이터, 람다, 튜플, 조기 리턴, 재귀 함수, 함수 리턴 개념을 적절히 활용해야 합니다.

# %%
add_list = []

#추가
def add_address(name: str, phone: str, email: str):
    add_list.append({"이름": name,"전화번호":phone,"이메일":email})

#전체 목록보기
def list_address():
    for i in add_list:
        print(i)

#검색
def search_address(name):
    for i in add_list:
         if i["이름"] == name:
               print(i)

#삭제
def del_address(name):
    for i in add_list:
         if i["이름"] == name:
            add_list.remove(i)
            print("삭제완료되었습지니다.")

while True:
    menu = input("원하는 메뉴를 선택하세요 (추가, 보기, 검색, 삭제, 종료): ")
    if menu == "종료":
        break
    elif menu == "추가":
        name = input("이름: ")
        phone = input("전화번호: ")
        email = input("이메일: ")
        add_address(name, phone, email)
    elif menu == "보기":
        list_address()
    elif menu == "검색":
        name = input("검색할 이름: ")
        search_address(name)
    elif menu == "삭제":
        name = input("삭제할 이름: ")
        del_address(name)
# Out:
# 원하는 동작을 선택하세요 (추가, 보기, 검색, 삭제, 종료): 추가
# 이름: 조주인
# 전화번호: 1-1
# 이메일: eun@eun.com
# 원하는 동작을 선택하세요 (추가, 보기, 검색, 삭제, 종료): 추가
# 이름: 조먼지
# 전화번호: 2-2
# 이메일: dust@dust.com
# 원하는 동작을 선택하세요 (추가, 보기, 검색, 삭제, 종료): 추가
# 이름: 조하루
# 전화번호: 3-3
# 이메일: day@day.com
# 원하는 동작을 선택하세요 (추가, 보기, 검색, 삭제, 종료): 보기
# {'이름': '조주인', '전화번호': '1-1', '이메일': 'eun@eun.com'}
# {'이름': '조먼지', '전화번호': '2-2', '이메일': 'dust@dust.com'}
# {'이름': '조하루', '전화번호': '3-3', '이메일': 'day@day.com'}
# 원하는 동작을 선택하세요 (추가, 보기, 검색, 삭제, 종료): 삭제
# 삭제할 이름: 조먼지
# 삭제완료되었습지니다.
# 원하는 동작을 선택하세요 (추가, 보기, 검색, 삭제, 종료): 보기
# {'이름': '조주인', '전화번호': '1-1', '이메일': 'eun@eun.com'}
# {'이름': '조하루', '전화번호': '3-3', '이메일': 'day@day.com'}
# 원하는 동작을 선택하세요 (추가, 보기, 검색, 삭제, 종료): 검색
# 검색할 이름: 조먼지
# 원하는 동작을 선택하세요 (추가, 보기, 검색, 삭제, 종료): 검색
# 검색할 이름: 조하루
# {'이름': '조하루', '전화번호': '3-3', '이메일': 'day@day.com'}
# 원하는 동작을 선택하세요 (추가, 보기, 검색, 삭제, 종료): 종료
