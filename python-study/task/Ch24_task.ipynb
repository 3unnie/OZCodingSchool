# %% [markdown]
# 사용자의 이름, 나이, 성별을 출력하는 함수 print_info를 작성하세요. 이 때, 모든 매개변수는 키워드 매개변수로만 받도록 하세요.

# %%
def print_info(**info):
        print(info)

print_info(이름="먼지",나이=0.8,성별="남")
# Out:
# {'이름': '먼지', '나이': 0.8, '성별': '남'}
