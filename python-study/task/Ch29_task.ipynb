# %% [markdown]
# 사용자로부터 3개의 숫자를 입력받아, 이를 튜플로 만든 후 최소값과 최대값을 출력하는 함수 min_max를 작성하세요.

# %%
def min_max(*nums):
    print(type(nums))
    return print(f"최소:{min(nums)}최대:{max(nums)}") #원래 가변매개변수타입은 튜플

min_max(1,4,6,2,6,8)
# Out:
# <class 'tuple'>
# 최소:1최대:8
