# %% [markdown]
# 여러분이 자주 사용하는 수학적 연산<br>
# (예: 삼각형 넓이, 원의 넓이, 직육면체의 넓이)을 수행하는 함수들을 포함하는 mymath.py라는 이름의 모듈을 만드세요.
#
# 이 모듈을 사용하여 작성된 함수들을 실제로 임포트하고 사용하는 간단한 프로그램을 작성하세요.

# %% [markdown]
# #mymath.py
# pi = 3.14
#
# #삼각형
# def get_tri(a):
#     return 2 * pi * radius
#
# #원의 넓이
# def get_circle(radius):
#     return pi * radius * radius

# %%
import mymath as m

try:
    width = int(input("가로를 입력해 주세요"))
    length = int(input("세로를 입력해 주세요"))
    height = int(input("높이를 입력해 주세요"))

except ValueError:
    print("숫자를 입력해주세요")

else:
    print("[삼각형넓이]:",m.get_tri(width,height))
    print("[원넓이]:",m.get_circle(width))
    print("[직육면체넓이]:",m.get_cuboid(width,height,length))
# Out:
# 가로를 입력해 주세요1
# 세로를 입력해 주세요1
# 높이를 입력해 주세요1
# [삼각형넓이]: 0.5
# [원넓이]: 3.14
# [직육면체넓이]: 6
