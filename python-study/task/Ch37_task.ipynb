# %% [markdown]
# datetime 모듈을 사용하여 현재 날짜와 시간을 출력하는 프로그램을 작성하세요.
#
# 또한, 사용자로부터 태어난 년도를 입력받아 현재 나이를 계산하여 출력하세요.

# %%
import datetime

today = datetime.datetime.now()
print(today.strftime("%Y{}%m{}%d{} %H{}%M{}%S{} ").format(*"년월일시분초"))

print("현재 나이는", today.year - int(input("[태어난 년도를 입력해주세요] : ")),"살 입니다.")
# Out:
# 2024년04월09일 19시20분22초
# [태어난 년도를 입력해주세요] : 2023
# 현재 나이는 1 살 입니다.
