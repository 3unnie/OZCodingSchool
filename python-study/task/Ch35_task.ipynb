# %% [markdown]
# 사용자로부터 여러 개의 숫자를 입력받아 리스트에 저장한 후, 사용자가 'done'이라고 입력할 때까지 계속 입력받으세요.
#
# - 입력 중 숫자가 아닌 값이 입력되면 ValueError를 처리
# - 숫자 외 값이 입력된 경우 어떤 값이 잘못 입력되었는지 사용자에게 알려주는 문구 출력<br>
#   (예: f"잘못된 값: {변수}. 숫자를 입력해주세요.")

# %%
nums = []

while True:
    try:
        num = input("숫자들을 입력해주세요(끝내고싶을시'done'입력)")
        if num == "done":
            break
        nums.append(int(num))
    except ValueError:
        print(f"잘못된 값: {num}. 숫자를 입력해주세요.")
    else:
        print(nums)
# Out:
# 숫자들을 입력해주세요(끝내고싶을시'done'입력)1
# [1]
# 숫자들을 입력해주세요(끝내고싶을시'done'입력)2
# [1, 2]
# 숫자들을 입력해주세요(끝내고싶을시'done'입력)3
# [1, 2, 3]
# 숫자들을 입력해주세요(끝내고싶을시'done'입력)r
# 잘못된 값: r. 숫자를 입력해주세요.
# 숫자들을 입력해주세요(끝내고싶을시'done'입력)done
